# %% [markdown]
# # Aula Prática 2 (guião)
# ### Semana de 21 a 25 de Setembro de 2026
# ### José Carlos Ramalho e Luís Cunha
# ### Sinopsis:
# Algoritmos de cálculo numérico envolvendo estruturas condicionais (if-elif-else) e cíclicas simples (while).

# %% [markdown]
# ### Exercício 1: Maior de 2 números
# - Especifique um programa que recebe dois valores e escreve na saída o maior.

# %%
a = int(input("Escolha um número: "))
b = int(input("Escolha outro número: "))
resultado = 0
if a > b:
    resultado = a
else:
    resultado = b
print (f"O valor mais alto é {resultado}")
# Out:
# 11

# %% [markdown]
# ### Exercício 2: Maior de 3 números
# - Especifique um programa que recebe três valores e escreve na saída o maior.

# %%
a = int(input("Escolha o 1º número: "))
b = int(input("Escolha o 2º número: "))
c = int(input("Escolha o 3º número: "))
resultado = 0

if a > b and a > c:
    resultado = a
elif b > a and b > c:
    resultado = b
else: resultado = c

print (f"O maior valor é {resultado}")
# Out:
# O maior valor é 100

# %% [markdown]
# ### Exercício 3: Sobrinhos do Pato Donald
#
# - Especifique um programa que lê um nome e se este for `Hugo`, `Luís` ou `Zé` identifica-o como sobrinho do Pato Donald, se for outro nome deve indicar que o mesmo não é sobrinho de nínguém conhecido.

# %%
guess = input ("Conhece os sobrinhos do Pato Donald? Se sim, diga o nome de um: ")
if guess == "Hugo" or guess == "Luís" or guess == "Zé":
    print ("É sobrinho do Pato Donald")
else: print ("Não é sobrinho do Pato Donald.")
# Out:
# Não é sobrinho do Pato Donald.
# Não é sobrinho do Pato Donald.
# Não é sobrinho do Pato Donald.

# %% [markdown]
# ### Exercício 4: Índice de Massa Corporal
# - Especifique um programa que recebe dois parâmetros, **peso**,**altura**, calcula o IMC corresponente e interpreta esse resultado.
# - Input: 53 e 1.56
# - Output: "O seu índice de massa corporal é **21.78** e encontra-se na categoria **Normal**"
#
# Valores para a interpretação:
# - Menor que 18,5 - Baixo peso
# - 18,5 a 24,9 - Normal
# - 25 a 29,9	- Excesso de peso
# - 30 a 34,9	- Obesidade grau I
# - 35 a 39,9	- Obesidade grau II
# - Maior que 40	- Obesidade grau III

# %%
h = float(input("Introduza a sua altura, em metros: "))
m = float(input("Introduza o seu peso, em KG: "))

IMC = m/(h*h)
categoria = ""

if IMC < 18.5:
    categoria = "Baixo Peso"
elif IMC >= 18.5 and IMC <=24.9:
    categoria = " Normal"
elif IMC >= 25 and IMC <= 29.9:
    categoria = "Excesso de peso"
elif IMC >= 30 and IMC <= 34.9:
    categoria = "Obesidade grau I"
elif IMC >= 35 and IMC <= 39.9:
    categoria = "Obesidade grau II"
elif IMC >= 40:
    categoria = "Obesidade grau III" 
print (f"O seu índice de massa corporal é {IMC:.2f} a sua categoria é {categoria}")
# Out:
# O seu índice de massa corporal é 19.15 a sua categoria é  Normal

# %% [markdown]
# ## Teoria: estrutura cíclica `while`
#
# Estrutura:
# ```python
#     while cond:
#         ação
#         ...
# ```

# %% [markdown]
# ### Exemplo: Somar os inteiros entre 1 e 10

# %%
soma = 0
i = 1
while i <= 10:
    soma = soma + i
    i = i + 1
print(soma)

# %% [markdown]
# ### Exercício 5: Soma de N números
# - Leia um número N;
# - Leia N números;
# - Imprima a soma dos N números.

# %%
soma = 0
ns = []
n = int(input("Quantos números quer que sejam somados? "))
i = 1
while i <= n:
    x = int(input("Escolha o seu número inteiro: "))
    ns.append(x)
    i+=1
total = sum (ns)

print (f"A soma dos números é = {total}")
# Out:
# A soma dos números é = 150

# %%
soma = 0
n = int(input("Quantos números quer que sejam somandos? "))
i = 1
while i <= n:
    x = int(input("Introduza um nº a ser somado: "))
    soma += x
    i+=1
print (f"A soma total é {soma}")
# Out:
# A soma total é 150

# %% [markdown]
# ### Exercício 6: O Maior de N números
# - Leia um número N;
# - Leia N números;
# - Imprima o maior dos N números.

# %%
ns = []
i = 1
n = int(input("Quantos números quer inserir? "))
while i <= n:
    x = int(input("Insira um número inteiro: "))
    ns.append (x)
    i+=1
maior = max (ns)
print (f"O maior valor que inseriu é {maior}")
# Out:
# O maior valor que inseriu é 100

# %%
n = int(input("Quantos números quer que sejam lidos? "))
i = 1
x = int(input("Introduza um número: "))
maior_valor = x
while i <= n-1:
    x = int(input("Introduza um número: "))
    if x > maior_valor:
        maior_valor = x
    else:
        maior_valor
    i+=1

print (f"O maior valor é {maior_valor}")
# Out:
# O maior valor é -1

# %%
def maiorN(N):
    

print(maiorN(3), maiorN(2))
# Out:
#   Cell In[15], line 4
#     print(maiorN(3), maiorN(2))
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %% [markdown]
# ### Exercício 7: O Menor de N números
# - Leia um número N;
# - Leia N números;
# - Imprima o menor dos N números.

# %%
n = int(input("Quantos números vão ser analisados: "))
i = 1
x = int(input("Introduza um valor: "))
menor_valor = x
while i <= n-1:
    x = int(input("Introduza um valor: "))
    if menor_valor > x:
        menor_valor = x
    else: menor_valor
    i+=1

print(f"O menor valor introduzido foi {menor_valor}")
# Out:
# O menor valor introduzido foi -1

# %% [markdown]
# ### Exercício 8: A Média de N números
# - Leia um número N;
# - Leia N números;
# - Imprima a média dos N números.

# %%
n = int(input("De quantos nºs quer fazer a média: "))
soma = 0
i = 1
while i <= n:
    x = int(input("Introduza um valor: "))
    soma += x
    i+=1

media = soma/n

print (f"A média é igual a {media:.2f}")
# Out:
# A média é igual a 30.0

# %% [markdown]
# ## Teoria: definição de uma função `def`
#
# Estrutura:
# ```python
#     def f1(param1, param2, ..., paramn):
#         ação1
#         ação2
#         ...
#         return resultado
# ```

# %% [markdown]
# ### Exemplo: Somar os números inteiros de 1 até N

# %%
def somatorio(n):
    i = 1
    soma = 0
    while i <= n:
        soma += i
        i+=1
    return (soma)

num = int(input("Introduza um número inteiro positivo:"))
print(somatorio(num))
# Out:
# 15

# %% [markdown]
# ### Exercício 9:
#
# * Use a função definida no exemplo anterior para escrever no monitor uma lista de pares: (n, somatorio(n));
# * Faça n variar entre 10 e 1000 com um salto de 10: 10, 20, 30, ..., 1000.

# %%
# Solução do exercício 9

def somatorio(n):
    i = 1
    soma = 0
    while i <= n:
        soma += i
        i+=1
    return (soma)
n = 10
while n < 1001:
    print (n, somatorio(n))
    n += 10
# Out:
# 10 55
# 20 210
# 30 465
# 40 820
# 50 1275
# 60 1830
# 70 2485
# 80 3240
# 90 4095
# 100 5050
# 110 6105
# 120 7260
# 130 8515
# 140 9870
# 150 11325
# 160 12880
# 170 14535
# 180 16290
# 190 18145
# 200 20100
# 210 22155
# 220 24310
# 230 26565
# 240 28920
# 250 31375
# 260 33930
# 270 36585
# 280 39340
# 290 42195
# 300 45150
# 310 48205
# 320 51360
# 330 54615
# 340 57970
# 350 61425
# 360 64980
# 370 68635
# 380 72390
# 390 76245
# 400 80200
# 410 84255
# 420 88410
# 430 92665
# 440 97020
# 450 101475
# 460 106030
# 470 110685
# 480 115440
# 490 120295
# 500 125250
# 510 130305
# 520 135460
# 530 140715
# 540 146070
# 550 151525
# 560 157080
# 570 162735
# 580 168490
# 590 174345
# 600 180300
# 610 186355
# 620 192510
# 630 198765
# 640 205120
# 650 211575
# 660 218130
# 670 224785
# 680 231540
# 690 238395
# 700 245350
# 710 252405
# 720 259560
# 730 266815
# 740 274170
# 750 281625
# 760 289180
# 770 296835
# 780 304590
# 790 312445
# 800 320400
# 810 328455
# 820 336610
# 830 344865
# 840 353220
# 850 361675
# 860 370230
# 870 378885
# 880 387640
# 890 396495
# 900 405450
# 910 414505
# 920 423660
# 930 432915
# 940 442270
# 950 451725
# 960 461280
# 970 470935
# 980 480690
# 990 490545
# 1000 500500

# %% [markdown]
# ### Exercício 10: Potência
# - Defina uma função **pot** que recebe dois parâmetros, **a** e **b**, e retorna o resultado de **a elevado à potência de b**.
# - Use esta função para escrever no monitor as potências de 2 com expoentes de 1 a 20.

# %%
# Solução do exercício 10

def pot(a,b):
    res = 1
    i = 1
    while i <= b:
        res *= a
        i+=1
    return (res)

n = 1

while n <= 20:
    print (pot (2,n))
    n+=1
# Out:
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# 2048
# 4096
# 8192
# 16384
# 32768
# 65536
# 131072
# 262144
# 524288
# 1048576

# %% [markdown]
# #### Potências de base 2 com expoente entre 0  e 20

# %%
# Solução do exercício 10

def pot(a,b):
    res = 1
    i = 1
    if b != 0:
        while i <= b:
            res *= a
            i+=1
    else: res
    return (res)

n = 0

while n <= 20:
    print (pot (2,n))
    n+=1
# Out:
# 1
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# 2048
# 4096
# 8192
# 16384
# 32768
# 65536
# 131072
# 262144
# 524288
# 1048576

# %% [markdown]
# ### Exercício 11: Série numérica
# - Defina uma função **serie** que recebe três parâmetros, **base**, **salto** e **nelems**, e escreve no monitor a série;
# - Invocada com: **serie(7, 4, 5)** escreveria: 7, 11, 15, 19, 23

# %%
def serie (a,b,c):
    i = 1
    x = a
    while i <= c:
        print (x)
        x += b
        i += 1
    pass

serie (7,4,5)
# Out:
# 7
# 11
# 15
# 19
# 23

# %% [markdown]
# ### Exercício 12: Desenhar um quadrado
# - Defina uma função **quad** que recebe um argumento, **n**, e desenha no monitor um quadrado usando o caráter '#';
# - O resultado da invocação dessa função com um argumento 3 deverá ser:
# ```
# ###
# ###
# ###
# ```

# %%
# Solução do exercício 12

n = int(input("Introduza um N: "))
i = 1
while i <= n:
    print ("#"*n)
    i+=1
# Out:
# #####
# #####
# #####
# #####
# #####

# %% [markdown]
# ### Exercício 13: Desenhar um quadrado
# - Defina uma função que desenhe no ecran (usando os caracteres # e _) um tabuleiro de xadrez;
# - O resultado da invocação dessa função com um argumento 5 deverá ser:
# ```
# #_#_#
# _#_#_
# #_#_#
# _#_#_
# #_#_#
# ```

# %%
# Solução do exercício 13

n = int(input("Introduza um N: "))
i = 1
while i <= n:
    if (i%2)!=0:
        print("#_#_#")
    else:
        print ("_#_#_")
    i+=1
# Out:
# #_#_#
# _#_#_
# #_#_#
# _#_#_
# #_#_#

# %% [markdown]
# ### Exercício 14: Índice de Massa Corporal
# - Defina uma função **imc** que recebe dois parâmetros, **peso**,**altura**, calcula o IMC corresponente e interpreta esse resultado.
# - imc(53,1.56) - Output: "O seu índice de massa corporal é **21.78** e encontra-se na categoria **Normal**"
# - imc(83,1.56) - Output: "O seu índice de massa corporal é **34.11** e encontra-se na categoria **Obesidade grau I**"
#
# Valores:
# - Menor que 18,5 - Baixo peso
# - 18,5 a 24,9 - Normal
# - 25 a 29,9	- Excesso de peso
# - 30 a 34,9	- Obesidade grau I
# - 35 a 39,9	- Obesidade grau II
# - Maior que 40	- Obesidade grau III

# %%
# Solução do exercício 14

def imc (a,b):
    conta = b/(a*a)
    return (conta)

h = float(input("Introduza a sua altura, em metros: "))
m = float(input("Introduza o seu peso, em KG: "))

IMC = imc(h,m)

if IMC < 18.5:
    categoria = "Baixo Peso"
elif IMC >= 18.5 and IMC <=24.9:
    categoria = " Normal"
elif IMC >= 25 and IMC <= 29.9:
    categoria = "Excesso de peso"
elif IMC >= 30 and IMC <= 34.9:
    categoria = "Obesidade grau I"
elif IMC >= 35 and IMC <= 39.9:
    categoria = "Obesidade grau II"
elif IMC >= 40:
    categoria = "Obesidade grau III" 

print (f"O seu índice de massa corporal é {IMC:.2f} e a sua categoria é {categoria}")
# Out:
# O seu índice de massa corporal é 24.111507464658473 e a sua categoria é  Normal

# %% [markdown]
# ### Exercício 15: Série de Fibonacci
# - Defina uma função **fib** que recebe um argumento, **n**, e escreve no monitor os primeiros n elementos da série de fibonacci;
# - A série de Fibonacci tem a seguinte definição matemática:
#     - Se n < 2 ==> 1
#     - Se n >= 2 ==> fib(n-1) + fib(n-2)

# %%
def fib (n):
    resultado = 0
    i = 1
    while i <= n:
        if i < 2:
            resultado = 1
        else:
            resultado = fib(n-1)+fib(n-2)
        i+=1
    return (resultado)

n = int(input("Introduza um n: "))
i = 1

while i <= n:
    print (fib(i))
    i+=1
# Out:
# 1
# 1
# 2
# 3
# 5
# 8
